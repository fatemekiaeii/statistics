# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
data=np.array([-20,-3,-2,-1,0,1,2,3,4,5,8,9,10,11,12,13,15,16,19,40,50])

# %%
q1=np.quantile(data,0.25)
q1
# Out:
# 1.0

# %%
q2=np.quantile(data,0.5)
q2
# Out:
# 8.0

# %%
q3=np.quantile(data,0.75)
q3
# Out:
# 13.0

# %%
iqr=q3-q1
iqr
# Out:
# 12.0

# %%
lv=q1-1.5*iqr
lv
# Out:
# -17.0

# %%
hv=q3+1.5*iqr
hv
# Out:
# 31.0

# %%
plt=plt.boxplot(data)

# %%
class1=np.array([45,79,78,79,81,85,89,93,95,98,99,100,110])

# %%
class2=np.array([130,140,141,150,170,175,190,200,205,210,280,290,350])

# %%
plt.boxplot([class1,class2],patch_artist =True );

# %% [markdown]
# # BAR GRAPH

# %%
grade=['a','b','c','d','e']

# %%
n=[5,10,8,3,2]

# %%
k=[0,1,2,3,4]

# %%
plt.bar(k,n,color='green')
plt.xlabel('grade')
plt.ylabel('number of student')
a=plt.xticks(k,grade)

# %% [markdown]
# # scatterPLlot

# %%
x=np.array([-3 ,-2 ,-1 ,0 ,1 ,2 ,3])
y=np.array([9, 4, 1,0 ,1 ,4, 9])

# %%
plt.scatter(x, y, c='r');

# %% [markdown]
# # histogram

# %%
data=np.array([1,1,1,2,2,3,3,4,4,4,4,5,5,5,6,7,8,7,8,8,8,8,11,12,13,13,13,13,14,15,16,19,20])

# %%
plt.hist(data,bins="auto",edgecolor="black")
plt.xlabel('value')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(data,bins=5,edgecolor="red")
plt.xlabel('value')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(data,bins="auto")
plt.xlabel('value')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
x=100+15*np.random.randn(1000)

# %%
n,bins,_=plt.hist(x,bins=40,edgecolor='black',normed=1)
y=mlab.normpdf(bins,100,15)
plt.plot(bins,y,'r')
# Out:
# C:\Users\Fatemeh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
n,bins,_=plt.hist(x,bins=40,edgecolor='black',normed=1)
